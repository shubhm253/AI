# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Automobile_data.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
def clean_numerical(column):
    mean = df[df[column]!="?"][column].astype(float).mean()
    df[column] = df[column].str.replace("?", str(mean)).astype(float)
    return df

# %%
def clean_categorical(column):
    mean = df[df[column]!="?"][column].astype(str).mode()
    df[column] = df[column].str.replace("?", str(mean)).astype(str)
    return df

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df["symboling"].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
df["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 168     5
# 94      5
# 74      5
# 95      5
# 65      5
# 102     5
# 103     5
# 85      5
# 106     4
# 122     4
# 118     4
# 93      4
# 148     4
# 154     3
# 101     3
# 137     3
# 83      3
# 125     3
# 115     3
# 89      2
# 197     2
# 145     2
# 194     2
# 164     2
# 113     2
# 188     2
# 153     2
# 192     2
# 87      2
# 158     2
# 129     2
# 119     2
# 110     2
# 108     2
# 81      2
# 77      1
# 142     1
# 256     1
# 121     1
# 231     1
# 107     1
# 98      1
# 186     1
# 90      1
# 78      1
# Name: normalized-losses, dtype: int64

# %%
clean_numerical("normalized-losses")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["normalized-losses"].value_counts()
# Out:
# 122.0    45
# 161.0    11
# 91.0      8
# 150.0     7
# 104.0     6
# 134.0     6
# 128.0     6
# 94.0      5
# 74.0      5
# 85.0      5
# 103.0     5
# 168.0     5
# 95.0      5
# 65.0      5
# 102.0     5
# 148.0     4
# 106.0     4
# 93.0      4
# 118.0     4
# 115.0     3
# 154.0     3
# 125.0     3
# 137.0     3
# 101.0     3
# 83.0      3
# 194.0     2
# 110.0     2
# 145.0     2
# 119.0     2
# 197.0     2
# 108.0     2
# 188.0     2
# 129.0     2
# 81.0      2
# 164.0     2
# 192.0     2
# 158.0     2
# 153.0     2
# 87.0      2
# 89.0      2
# 113.0     2
# 121.0     1
# 98.0      1
# 186.0     1
# 78.0      1
# 107.0     1
# 77.0      1
# 90.0      1
# 256.0     1
# 231.0     1
# 142.0     1
# Name: normalized-losses, dtype: int64

# %%
df["make"].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# subaru           12
# volkswagen       12
# peugot           11
# volvo            11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
df["fuel-type"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
df["aspiration"].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df["num-of-doors"].value_counts()
# Out:
# four    114
# two      89
# ?         2
# Name: num-of-doors, dtype: int64

# %%
clean_categorical("num-of-doors")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["num-of-doors"].value_counts()
# Out:
# four                        114
# two                          89
# 0    four\ndtype: object      2
# Name: num-of-doors, dtype: int64

# %%
df["body-style"].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
df["drive-wheels"].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive-wheels, dtype: int64

# %%
df["engine-location"].value_counts()
# Out:
# front    202
# rear       3
# Name: engine-location, dtype: int64

# %%
df["wheel-base"].value_counts()
# Out:
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 98.4      7
# 97.3      7
# 96.3      6
# 107.9     6
# 98.8      6
# 99.1      6
# 104.3     6
# 100.4     6
# 93.1      5
# 97.2      5
# 102.4     5
# 109.1     5
# 95.9      5
# 101.2     4
# 97.0      4
# 114.2     4
# 95.3      4
# 105.8     3
# 103.5     3
# 110.0     3
# 89.5      3
# 99.8      2
# 86.6      2
# 113.0     2
# 104.5     2
# 104.9     2
# 88.6      2
# 96.9      2
# 91.3      2
# 115.6     2
# 102.9     2
# 96.1      2
# 103.3     2
# 112.0     1
# 99.5      1
# 88.4      1
# 99.2      1
# 96.0      1
# 102.0     1
# 106.7     1
# 93.0      1
# 99.4      1
# 93.3      1
# 102.7     1
# 120.9     1
# 95.1      1
# 96.6      1
# 94.3      1
# 108.0     1
# Name: wheel-base, dtype: int64

# %%
df["length"].value_counts()
# Out:
# 157.3    15
# 188.8    11
# 166.3     7
# 171.7     7
# 186.7     7
# 165.3     6
# 177.8     6
# 176.2     6
# 186.6     6
# 176.8     5
# 172.0     5
# 175.6     5
# 173.2     5
# 172.4     4
# 169.0     4
# 168.7     4
# 198.9     4
# 168.9     4
# 192.7     3
# 158.7     3
# 155.9     3
# 170.7     3
# 169.7     3
# 159.1     3
# 150.0     3
# 175.4     3
# 168.8     2
# 167.3     2
# 170.2     2
# 173.4     2
#          ..
# 173.6     2
# 166.8     2
# 187.5     1
# 165.6     1
# 178.5     1
# 172.6     1
# 178.4     1
# 181.5     1
# 208.1     1
# 159.3     1
# 197.0     1
# 162.4     1
# 165.7     1
# 158.8     1
# 180.3     1
# 169.1     1
# 157.1     1
# 156.9     1
# 171.2     1
# 163.4     1
# 178.2     1
# 191.7     1
# 199.2     1
# 141.1     1
# 181.7     1
# 157.9     1
# 177.3     1
# 175.7     1
# 193.8     1
# 183.1     1
# Name: length, Length: 75, dtype: int64

# %%
df["width"].value_counts()
# Out:
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 66.3     6
# 64.2     6
# 67.2     6
# 65.6     6
# 67.9     5
# 66.9     5
# 68.9     4
# 64.8     4
# 65.7     4
# 65.0     3
# 63.9     3
# 71.4     3
# 71.7     3
# 70.3     3
# 64.6     2
# 64.1     2
# 67.7     2
# 66.1     2
# 68.3     2
# 69.6     2
# 61.8     1
# 72.0     1
# 68.8     1
# 62.5     1
# 66.0     1
# 63.4     1
# 70.5     1
# 72.3     1
# 68.0     1
# 70.9     1
# 66.2     1
# 66.4     1
# 60.3     1
# 70.6     1
# 66.6     1
# Name: width, dtype: int64

# %%
df["height"].value_counts()
# Out:
# 50.8    14
# 52.0    12
# 55.7    12
# 54.5    10
# 54.1    10
# 55.5     9
# 56.7     8
# 54.3     8
# 51.6     7
# 56.1     7
# 52.6     7
# 50.2     6
# 53.0     6
# 54.9     6
# 52.8     6
# 53.7     5
# 55.1     5
# 50.6     5
# 53.3     4
# 58.7     4
# 49.6     4
# 57.5     3
# 53.5     3
# 49.7     3
# 59.1     3
# 56.2     3
# 52.5     3
# 49.4     2
# 48.8     2
# 56.3     2
# 54.4     2
# 59.8     2
# 56.5     2
# 54.7     2
# 51.4     2
# 53.9     2
# 50.5     2
# 56.0     1
# 51.0     1
# 52.4     1
# 55.4     1
# 55.6     1
# 53.1     1
# 58.3     1
# 47.8     1
# 54.8     1
# 55.9     1
# 53.2     1
# 55.2     1
# Name: height, dtype: int64

# %%
df["curb-weight"].value_counts()
# Out:
# 2385    4
# 1989    3
# 1918    3
# 2275    3
# 3230    2
# 2410    2
# 3252    2
# 2337    2
# 2403    2
# 2414    2
# 2145    2
# 3139    2
# 2395    2
# 1876    2
# 1874    2
# 2128    2
# 1967    2
# 2380    2
# 4066    2
# 2756    2
# 2579    2
# 3075    2
# 2535    2
# 2548    2
# 1909    2
# 2191    2
# 2290    2
# 2024    2
# 2300    2
# 3151    1
#        ..
# 2707    1
# 3217    1
# 3770    1
# 2190    1
# 2094    1
# 2302    1
# 2443    1
# 2954    1
# 2261    1
# 2695    1
# 3740    1
# 3485    1
# 1951    1
# 2976    1
# 2952    1
# 2563    1
# 1971    1
# 1985    1
# 3505    1
# 2480    1
# 2734    1
# 2221    1
# 2670    1
# 2926    1
# 1950    1
# 3750    1
# 1956    1
# 2037    1
# 2465    1
# 2304    1
# Name: curb-weight, Length: 171, dtype: int64

# %%
df["engine-type"].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64

# %%
df["engine-size"].value_counts()
# Out:
# 122    15
# 92     15
# 98     14
# 97     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 121     6
# 146     6
# 181     6
# 91      5
# 156     5
# 136     5
# 130     4
# 183     4
# 194     3
# 164     3
# 171     3
# 209     3
# 70      3
# 234     2
# 131     2
# 134     2
# 140     2
# 258     2
# 132     2
# 111     1
# 103     1
# 145     1
# 151     1
# 119     1
# 173     1
# 203     1
# 80      1
# 79      1
# 326     1
# 61      1
# 308     1
# 304     1
# 161     1
# Name: engine-size, dtype: int64

# %%
df["num-of-cylinders"].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# twelve      1
# three       1
# Name: num-of-cylinders, dtype: int64

# %%
df["fuel-system"].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# spfi     1
# mfi      1
# Name: fuel-system, dtype: int64

# %%
df["bore"].value_counts()
# Out:
# 3.62    23
# 3.19    20
# 3.15    15
# 2.97    12
# 3.03    12
# 3.46     9
# 3.43     8
# 3.31     8
# 3.78     8
# 2.91     7
# 3.27     7
# 3.05     6
# 3.58     6
# 3.39     6
# 3.54     6
# 3.7      5
# 3.01     5
# ?        4
# 3.35     4
# 3.74     3
# 3.17     3
# 3.59     3
# 3.5      2
# 3.24     2
# 3.94     2
# 3.63     2
# 3.8      2
# 3.33     2
# 3.47     2
# 3.13     2
# 2.68     1
# 3.76     1
# 3.08     1
# 2.99     1
# 2.92     1
# 3.61     1
# 3.6      1
# 2.54     1
# 3.34     1
# Name: bore, dtype: int64

# %%
clean_numerical("bore")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["stroke"].value_counts()
# Out:
# 3.4     20
# 3.03    14
# 3.15    14
# 3.23    14
# 3.39    13
# 2.64    11
# 3.29     9
# 3.35     9
# 3.46     8
# 3.41     6
# 3.27     6
# 3.07     6
# 3.19     6
# 3.5      6
# 3.11     6
# 3.58     6
# 3.64     5
# 3.52     5
# 3.86     4
# ?        4
# 3.54     4
# 3.47     4
# 3.9      3
# 2.9      3
# 2.19     2
# 3.08     2
# 4.17     2
# 2.68     2
# 2.8      2
# 3.1      2
# 3.16     1
# 2.87     1
# 2.76     1
# 2.36     1
# 3.21     1
# 3.12     1
# 2.07     1
# Name: stroke, dtype: int64

# %%
clean_numerical("stroke")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["compression-ratio"].value_counts()
# Out:
# 9.00     46
# 9.40     26
# 8.50     14
# 9.50     13
# 9.30     11
# 8.70      9
# 9.20      8
# 8.00      8
# 7.00      7
# 21.00     5
# 7.50      5
# 9.60      5
# 23.00     5
# 8.40      5
# 8.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 8.80      3
# 7.70      2
# 8.10      2
# 9.31      1
# 21.90     1
# 22.00     1
# 11.50     1
# 9.41      1
# 10.10     1
# 9.10      1
# 22.70     1
# 7.80      1
# Name: compression-ratio, dtype: int64

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 101     6
# 88      6
# 62      6
# 160     6
# 97      5
# 84      5
# 102     5
# 76      5
# 145     5
# 82      5
# 111     4
# 86      4
# 92      4
# 123     4
# 121     3
# 85      3
# 207     3
# 152     3
# 90      3
# 73      3
# 182     3
# 56      2
# ?       2
# 52      2
# 112     2
# 100     2
# 162     2
# 184     2
# 94      2
# 176     2
# 156     2
# 155     2
# 161     2
# 55      1
# 135     1
# 262     1
# 115     1
# 60      1
# 48      1
# 58      1
# 154     1
# 142     1
# 72      1
# 120     1
# 106     1
# 200     1
# 134     1
# 175     1
# 64      1
# 143     1
# 140     1
# 288     1
# 78      1
# Name: horsepower, dtype: int64

# %%
clean_numerical("horsepower")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["peak-rpm"].value_counts()
# Out:
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5250     7
# 5800     7
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5900     3
# 5100     3
# 4250     3
# 4400     3
# 6600     2
# ?        2
# 5300     1
# 5750     1
# 5600     1
# 4900     1
# 4650     1
# Name: peak-rpm, dtype: int64

# %%
clean_numerical("peak-rpm")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df["city-mpg"].value_counts()
# Out:
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# 26    12
# 23    12
# 21     8
# 30     8
# 25     8
# 38     7
# 28     7
# 37     6
# 16     6
# 22     4
# 15     3
# 18     3
# 29     3
# 20     3
# 14     2
# 49     1
# 47     1
# 32     1
# 33     1
# 34     1
# 35     1
# 36     1
# 45     1
# 13     1
# Name: city-mpg, dtype: int64

# %%
df["highway-mpg"].value_counts()
# Out:
# 25    19
# 24    17
# 38    17
# 30    16
# 32    16
# 34    14
# 37    13
# 28    13
# 29    10
# 33     9
# 31     8
# 22     8
# 23     7
# 27     5
# 43     4
# 41     3
# 42     3
# 26     3
# 20     2
# 19     2
# 18     2
# 16     2
# 36     2
# 39     2
# 46     2
# 47     2
# 53     1
# 50     1
# 17     1
# 54     1
# Name: highway-mpg, dtype: int64

# %%
df["price"].value_counts()
# Out:
# ?        4
# 8921     2
# 16500    2
# 8845     2
# 9279     2
# 8495     2
# 18150    2
# 7609     2
# 7295     2
# 7957     2
# 13499    2
# 6229     2
# 7898     2
# 7775     2
# 5572     2
# 6692     2
# 18280    1
# 17950    1
# 5118     1
# 16925    1
# 6795     1
# 22470    1
# 12764    1
# 13415    1
# 30760    1
# 13860    1
# 15645    1
# 6295     1
# 6785     1
# 6338     1
#         ..
# 9988     1
# 9495     1
# 6855     1
# 15985    1
# 12964    1
# 8249     1
# 7995     1
# 6849     1
# 16630    1
# 11245    1
# 9895     1
# 6095     1
# 10245    1
# 8449     1
# 18420    1
# 36880    1
# 15580    1
# 7975     1
# 22018    1
# 13200    1
# 6989     1
# 8949     1
# 12940    1
# 7799     1
# 14869    1
# 19045    1
# 12945    1
# 11248    1
# 17199    1
# 40960    1
# Name: price, Length: 187, dtype: int64

# %%
clean_numerical("price")
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %%
df['make'].value_counts().plot(kind='bar')

# %%
sns.lmplot('price',"engine-size",data=df)
# Out:
# C:\Users\SONY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['engine-type'].value_counts().plot(kind='bar')
# Out:
#      symboling  normalized-losses fuel-type aspiration  \
# 0            3              122.0       gas        std
# 1            3              122.0       gas        std
# 2            1              122.0       gas        std
# 3            2              164.0       gas        std
# 4            2              164.0       gas        std
# 5            2              122.0       gas        std
# 6            1              158.0       gas        std
# 7            1              122.0       gas        std
# 8            1              158.0       gas      turbo
# 9            0              122.0       gas      turbo
# 10           2              192.0       gas        std
# 11           0              192.0       gas        std
# 12           0              188.0       gas        std
# 13           0              188.0       gas        std
# 14           1              122.0       gas        std
# 15           0              122.0       gas        std
# ...

# %%
df['num-of-cylinders'].value_counts().plot(kind='bar',color='black')
plt.title("vehicles-cylinder")
plt.ylabel('Vehicles')
plt.xlabel('Cylinders')
# Out:
# Text(0.5,0,'Cylinders')

# %%
df['fuel-type'].value_counts().plot(kind='bar',color='yellow')
plt.title("fuel-type-vehicles")
plt.ylabel('Number of Vehicles')
plt.xlabel('fuel-type')
# Out:
# Text(0.5,0,'fuel-type')

# %%
df['engine-location'].value_counts().plot(kind='barh',color='red')
plt.title("engine location-vehicles")
plt.ylabel('Number of vehicles')
plt.xlabel('engine-location')
# Out:
# Text(0.5,0,'engine-location')

# %%
df['aspiration'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("aspiration-vehicles")
plt.ylabel('Number of vehicles')
plt.xlabel('aspiration')
# Out:
# Text(0.5,0,'aspiration')

# %%
sns.catplot(x="body-style", y="height", hue="make", kind="swarm", data=df)

# %%
sns.catplot(x="num-of-doors", y="length",hue="drive-wheels",kind="bar", data=df)
# Out:
# C:\Users\SONY\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x="fuel-system", y="stroke",
            col="body-style", aspect=.6,
            kind="swarm", data=df)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="make", y="price", data=df)
